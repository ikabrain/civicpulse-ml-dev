# %% [markdown]
# # [YOLO + OCR for License Plate Recognition](https://www.youtube.com/watch?v=9KnARRqbkzY)
# ---

# %% [markdown]
# Before running a notebook for the first time, install the required dependencies with:
#
# ```bash
# 	make requirements-nb
# ```

# %% [markdown]
# ## Importing dataset from Roboflow
# ---

# %%
from roboflow import Roboflow

# %% [markdown]
# ### RoboFlow API

# %% [markdown]
# Add your Roboflow API key to a `.env` file in the project root:
# ```
# ROBOFLOW_API_KEY=your_api_key_here
# ```

# %%
from civicpulseML.config import ROBOFLOW_API_KEY

print("RoboFlow API Key:", ROBOFLOW_API_KEY)
# Out:
# RoboFlow API Key: gZSczypueiYBVlXTnSV0

# %% [markdown]
# ### RoboFlow dataset import

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="unauthorized")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(11)
dataset = version.download("yolov8")
